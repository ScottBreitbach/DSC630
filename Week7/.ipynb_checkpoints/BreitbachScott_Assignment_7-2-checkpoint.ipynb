# %% [markdown]
# # Scott Breitbach
# ## 16-Oct-2021
# ## DSC630, Assignment 7.2: Create Optimal Hotel Recommendations

# %% [markdown]
# 1) Start by doing some exploratory analysis of this data to help understand how to make a prediction on the hotel cluster the user is likely to select.
# 2) Then, split train.csv into a training and test set (feel free to select a smaller random subset of train.csv).
# 3) Then, build at least two prediction models from the training set, and report the accuracies on the test set.

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Load Libraries
import numpy as np
import pandas as pd
import random
random.seed(42)

# %% [markdown]
# Get a random sample of size *s*:

# %%
# %%time
# Load a random subset of rows from the data set
file = '../Week7/expedia-hotel-recommendations/train.csv'

# n = 37670293 # number of records in file
n = sum(1 for line in open(file)) - 1
s = 100000 # desired sample size
# skip = sorted(random.sample(range(n), n-s))
skip = sorted(random.sample(range(1, n+1), n-s))
# colNames = pd.read_csv(file, nrows=1).columns
# ranDF = pd.read_csv(file, skiprows=skip, names=colNames)
ranDF = pd.read_csv(file, skiprows=skip)
# Out:
# Wall time: 1min 31s

# %%
# Drop any rows containing null values
ranDF.dropna(axis=0, inplace=True)

# %% [markdown]
# Get an idea of what the data set looks like:

# %%
ranDF.shape
# Out:
# (6387, 24)

# %%
ranDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6387 entries, 0 to 9996
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date_time                  6387 non-null   object
#  1   site_name                  6387 non-null   int64
#  2   posa_continent             6387 non-null   int64
#  3   user_location_country      6387 non-null   int64
#  4   user_location_region       6387 non-null   int64
#  5   user_location_city         6387 non-null   int64
#  6   orig_destination_distance  6387 non-null   float64
#  7   user_id                    6387 non-null   int64
#  8   is_mobile                  6387 non-null   int64
#  9   is_package                 6387 non-null   int64
#  10  channel                    6387 non-null   int64
#  11  srch_ci                    6387 non-null   object
#  12  srch_co                    6387 non-null   object
#  13  srch_adults_cnt            6387 non-null   int64
#  14  srch_children_cnt          6387 non-null   int64
#  15  srch_rm_cnt                6387 non-null   int64
#  16  srch_destination_id        6387 non-null   int64
#  17  srch_destination_type_id   6387 non-null   int64
#  18  is_booking                 6387 non-null   int64
#  19  cnt                        6387 non-null   int64
#  20  hotel_continent            6387 non-null   int64
#  21  hotel_country              6387 non-null   int64
#  22  hotel_market               6387 non-null   int64
#  23  hotel_cluster              6387 non-null   int64
# dtypes: float64(1), int64(20), object(3)
# memory usage: 1.2+ MB

# %%
ranDF.head()
# Out:
#              date_time  site_name  posa_continent  user_location_country  \
# 0  2014-08-11 08:24:33          2               3                     66
# 1  2014-08-13 13:41:21          2               3                     66
# 2  2014-06-12 07:29:47         11               3                    205
# 3  2014-12-29 12:10:40          2               3                     66
# 5  2014-12-17 20:43:04          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   348               48862                  2234.2641
# 1                   348               48862                   341.2798
# 2                   354               43201                    45.6136
# 3                   363               25671                   105.9578
# 5                   314                4868                    22.9187
#
#    user_id  is_mobile  is_package  ...  srch_children_cnt srch_rm_cnt  \
# 0       12          0           0  ...                  0           1
# 1    23569          0           0  ...                  0           1
# 2    28560          0           0  ...                  0           1
# 3    31638          0           0  ...                  0           1
# 5    60466          0           0  ...                  0           1
#
#   srch_destination_id  srch_destination_type_id  is_booking  cnt  \
# 0                8250                         1           0    1
# 1                8287                         1           0    2
# 2               12951                         5           0    1
# 3               45631                         6           0    1
# 5               25703                         6           0    1
#
#    hotel_continent  hotel_country  hotel_market  hotel_cluster
# 0                2             50           628              1
# 1                2            198           397              9
# 2                2            198           397             33
# 3                2             50           675             70
# 5                2             50           688             50
#
# [5 rows x 24 columns]

# %% [markdown]
# Go through each variable to look at distributions:

# %%
# Get counts of values for categories
ranDF.user_location_region.value_counts()
# Out:
# 174    1030
# 348     423
# 354     355
# 442     352
# 220     345
#        ...
# 344       1
# 788       1
# 199       1
# 370       1
# 441       1
# Name: user_location_region, Length: 149, dtype: int64

# %% [markdown]
# Plot histograms

# %%
# Load Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set up chart style
sns.set_style("whitegrid")

# Set up the figure size
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 5)

# %%
# plot histograms
hist = ranDF.hist(bins=20)

# %%
# Function for plotting a histogram, given column and dataframe
def makeHistogram(var, df=ranDF):
    # Create a histogram from a DataFrame variable
    plt.hist(df[var], bins=40)
    plt.xlabel(var, fontsize=20)
    plt.ylabel('Counts', fontsize=20)
    plt.tick_params(axis='both', labelsize=15)
    plt.show()

# %%
# %%time
# # Plot each variable in the dataframe
# for i in colNames:
#     makeHistogram(i)

# %% [markdown]
# Even though they are all represented numerically, the majority of features are categorical and will need to be treated as such. Many have one dominant value so I may convert those to binary in an effort to even them out.

# %%
# Get list of date formatted columns
datCols = ['date_time', 'srch_ci', 'srch_co']

# Get list of categorical variable columns
catCols = ['site_name', 'posa_continent', 'user_location_country', 
           'user_location_region', 'user_location_city', 'user_id', 
           'channel', 'srch_destination_id', 'srch_destination_type_id', 
           'hotel_continent', 'hotel_country', 'hotel_market', 'hotel_cluster']

# Get list of continuous variable columns
numCols = ['orig_destination_distance', 'srch_adults_cnt', 'srch_children_cnt', 
           'srch_rm_cnt', 'cnt']
           
# List of yes/no binary variable columns
ynCols = ['is_mobile', 'is_package', 'is_booking']

# %% [markdown]
# Chart categorical variables (boxplot)

# %%
# %%time
# # Set up chart style
# sns.set_style("whitegrid")

# # Make box plots for each categorical variable
# plt.rcParams.update({'figure.max_open_warning': 0}) # eliminate warning
# for variable in catCols:
#     plt.figure()
#     sns.boxplot(x = variable, y = 'hotel_cluster', data = ranDF)

# %% [markdown]
# Chart binary variables (boxplot)

# %%
# %%time
# # Set up chart style
# sns.set_style("whitegrid")

# # Make box plots for each binary variable
# plt.rcParams.update({'figure.max_open_warning': 0}) # eliminate warning
# for variable in ynCols:
#     plt.figure()
#     sns.boxplot(x = variable, y = 'hotel_cluster', data = ranDF)

# %% [markdown]
# Chart datetime variables (scatter)

# %%
# %%time
# # Make scatter plots for each datetime variable
# for variable in datCols:
#     plt.scatter(x= variable, y = 'hotel_cluster', data = ranDF)
#     plt.xlabel(variable)
#     plt.ylabel('Hotel Cluster')
#     plt.show()

# %% [markdown]
# Chart numerical variables (scatter)

# %%
# %%time
# # Make scatter plots for each numerical variable
# for variable in numCols:
#     plt.scatter(x= variable, y = 'hotel_cluster', data = ranDF)
#     plt.xlabel(variable)
#     plt.ylabel('Hotel Cluster')
#     plt.show()

# %% [markdown]
# Boxplots and scatter plots against the target variable weren't that useful because 'hotel_cluster' is a categorical variable.

# %% [markdown]
# Look for correlations using bivariate distribution plots

# %%
# %%time
# Plot bivariate distributions
for variable in catCols:
    plt.figure()
    sns.displot(x = variable, y = 'hotel_cluster', data = ranDF)
# Out:
# <timed exec>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Wall time: 1.77 s

# %% [markdown]
# Again, we're dealing with uneven distributions. So, while this is slightly better, it doesn't provide much more information.

# %% [markdown]
# ## Features

# %% [markdown]
# Time to manually go through each variable and make transformations:
# * date_time: Add Day of Week / Month of Year
# * site_name: Make binary (2 or not 2)
# * posa_continent: Make binary (3 or not 3)
# * user_location_country: Make binary 66 or not 66 (note: 15% of data was 205)
# * user_location_region: Group everything that's >500? (note: 146 unique regions)
#   * Binning might be preferred
# * ?bin? user_location_city: Leave for now (1814 unique vals 😯)
#   * Binning might be preferred
# * ?xform? orig_destination_distance: Leave for now
#   * Skews right; Consider transforming
# * user_id: Ignore for modeling
#   * Could potentially use counts of user instances
# * is_mobile: Binary, leave as is
# * is_package: Binary, leave as is
# * channel: Leave for now
#   * Could make binary (9 or not 9)
# * srch_ci / srch_co: Create Day of Week columns and 'length_of_stay'
# * srch_adults_cnt: Leave as is
# * srch_children_cnt: Leave as is
# * srch_rm_cnt: Leave as is
# * srch_destination_id: Leave as is
#   * Binning might be preferred
# * srch_destination_type_id: Leave as is
# * is_booking: Binary, leave as is
# * cnt: Leave as is
#   * Skews right; Consider transforming
# * hotel_continent: Leave as is
#   * Could make binary (2 or not 2)
# * hotel_country: Make binary (50 or not 50)
# * hotel_market: Leave as is
#   * Binning might be preferred
# * hotel_cluster: TARGET VARIABLE

# %%
# Save data
ranDF.to_csv('ranDF.csv', index=False)

# %%
# change data types
def change_dtype(cols, to_dtype, df=ranDF):
    for col in cols:
        df[col] = df[col].astype(to_dtype)

# %%
# Reassign some data types
change_dtype(catCols, 'category', ranDF)
change_dtype(ynCols, 'int8', ranDF)
change_dtype(datCols, 'datetime64', ranDF)

# %%
# Converts a column to binary based on matching / not matching value
def cat_to_binary(row, col, val):
    if row[col] == val:
        return 1
    return 0

# %%
# Converts anything over a particular value to that value
def bin_vals(row, col, val):
    if row[col] > val:
        return val
    return row[col]

# %%
# Data Transformations and new feature creation
ranDF['date_time_DoW'] = ranDF.date_time.dt.day_name()
ranDF['date_time_MoY'] = ranDF.date_time.dt.month_name()
ranDF['site_name_2'] = ranDF.apply(lambda row: cat_to_binary(row, 'site_name', 2), axis=1)
ranDF['posa_continent_3'] = ranDF.apply(lambda row: cat_to_binary(row, 'posa_continent', 3), axis=1)
ranDF['user_location_country_66'] = ranDF.apply(lambda row: cat_to_binary(row, 'user_location_country', 66), axis=1)
ranDF['user_location_region'] = ranDF.apply(lambda row: bin_vals(row, 'user_location_region', 500), axis=1)
ranDF['srch_ci_DoW'] = ranDF.srch_ci.dt.day_name()
ranDF['srch_co_DoW'] = ranDF.srch_co.dt.day_name()
ranDF['length_of_stay'] = (ranDF['srch_co'] - ranDF['srch_ci'])
ranDF['hotel_country'] = ranDF.apply(lambda row: cat_to_binary(row, 'hotel_country', 50), axis=1)

# %% [markdown]
# ### Create Dummy Variables

# %%
def getDummies(df):
    '''Creates dummy variables from categorical variables, adds them
    to the dataframe and returns the new dataframe with dummy vars'''
    dummyDF = df.copy()
    catList = dummyDF.select_dtypes(include=['object']).columns.tolist()
    for i in catList:
        dummies = pd.get_dummies(dummyDF[i], prefix=i)
        dummyDF = pd.concat([dummyDF, dummies], axis=1)
    return dummyDF

# %%
# Create dataframe with dummy variables
ranDF = getDummies(ranDF)
ranDF.shape
# Out:
# (6387, 65)

# %% [markdown]
# Reorder columns

# %%
# Reorder / select columns
newColOrder = ['date_time_DoW', 'date_time_MoY', 'site_name_2', 'posa_continent_3',
       'user_location_country_66', 'user_location_region',
       'user_location_city', 'orig_destination_distance', 'is_mobile',
       'is_package', 'channel', 'srch_ci_DoW', 'srch_co_DoW', 'length_of_stay',
       'srch_adults_cnt', 'srch_children_cnt', 'srch_rm_cnt',
       'srch_destination_id', 'srch_destination_type_id', 'is_booking', 'cnt',
       'hotel_continent', 'hotel_country', 'hotel_market', 
       'date_time_DoW_Friday', 'date_time_DoW_Monday',
       'date_time_DoW_Saturday', 'date_time_DoW_Sunday',
       'date_time_DoW_Thursday', 'date_time_DoW_Tuesday',
       'date_time_DoW_Wednesday', 'date_time_MoY_April',
       'date_time_MoY_August', 'date_time_MoY_December',
       'date_time_MoY_February', 'date_time_MoY_January', 'date_time_MoY_July',
       'date_time_MoY_June', 'date_time_MoY_March', 'date_time_MoY_May',
       'date_time_MoY_November', 'date_time_MoY_October',
       'date_time_MoY_September', 'srch_ci_DoW_Friday', 'srch_ci_DoW_Monday',
       'srch_ci_DoW_Saturday', 'srch_ci_DoW_Sunday', 'srch_ci_DoW_Thursday',
       'srch_ci_DoW_Tuesday', 'srch_ci_DoW_Wednesday', 'srch_co_DoW_Friday',
       'srch_co_DoW_Monday', 'srch_co_DoW_Saturday', 'srch_co_DoW_Sunday',
       'srch_co_DoW_Thursday', 'srch_co_DoW_Tuesday', 'srch_co_DoW_Wednesday',
              'hotel_cluster']
ranDF = ranDF[newColOrder]
ranDF.shape
# Out:
# (6387, 58)

# %%
# Look at variables
ranDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6387 entries, 0 to 9996
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date_time_DoW              6387 non-null   object
#  1   date_time_MoY              6387 non-null   object
#  2   site_name_2                6387 non-null   int64
#  3   posa_continent_3           6387 non-null   int64
#  4   user_location_country_66   6387 non-null   int64
#  5   user_location_region       6387 non-null   int64
#  6   user_location_city         6387 non-null   category
#  7   orig_destination_distance  6387 non-null   float64
#  8   is_mobile                  6387 non-null   int8
#  9   is_package                 6387 non-null   int8
#  10  channel                    6387 non-null   category
#  11  srch_ci_DoW                6387 non-null   object
#  12  srch_co_DoW                6387 non-null   object
#  13  length_of_stay             6387 non-null   timedelta64[ns]
#  14  srch_adults_cnt            6387 non-null   int64
#  15  srch_children_cnt          6387 non-null   int64
#  16  srch_rm_cnt                6387 non-null   int64
#  17  srch_destination_id        6387 non-null   category
#  18  srch_destination_type_id   6387 non-null   category
#  19  is_booking                 6387 non-null   int8
#  20  cnt                        6387 non-null   int64
#  21  hotel_continent            6387 non-null   category
#  22  hotel_country              6387 non-null   int64
#  23  hotel_market               6387 non-null   category
#  24  date_time_DoW_Friday       6387 non-null   uint8
#  25  date_time_DoW_Monday       6387 non-null   uint8
#  26  date_time_DoW_Saturday     6387 non-null   uint8
#  27  date_time_DoW_Sunday       6387 non-null   uint8
#  28  date_time_DoW_Thursday     6387 non-null   uint8
#  29  date_time_DoW_Tuesday      6387 non-null   uint8
#  30  date_time_DoW_Wednesday    6387 non-null   uint8
#  31  date_time_MoY_April        6387 non-null   uint8
#  32  date_time_MoY_August       6387 non-null   uint8
#  33  date_time_MoY_December     6387 non-null   uint8
#  34  date_time_MoY_February     6387 non-null   uint8
#  35  date_time_MoY_January      6387 non-null   uint8
#  36  date_time_MoY_July         6387 non-null   uint8
#  37  date_time_MoY_June         6387 non-null   uint8
#  38  date_time_MoY_March        6387 non-null   uint8
#  39  date_time_MoY_May          6387 non-null   uint8
#  40  date_time_MoY_November     6387 non-null   uint8
#  41  date_time_MoY_October      6387 non-null   uint8
#  42  date_time_MoY_September    6387 non-null   uint8
#  43  srch_ci_DoW_Friday         6387 non-null   uint8
#  44  srch_ci_DoW_Monday         6387 non-null   uint8
#  45  srch_ci_DoW_Saturday       6387 non-null   uint8
#  46  srch_ci_DoW_Sunday         6387 non-null   uint8
#  47  srch_ci_DoW_Thursday       6387 non-null   uint8
#  48  srch_ci_DoW_Tuesday        6387 non-null   uint8
#  49  srch_ci_DoW_Wednesday      6387 non-null   uint8
#  50  srch_co_DoW_Friday         6387 non-null   uint8
#  51  srch_co_DoW_Monday         6387 non-null   uint8
#  52  srch_co_DoW_Saturday       6387 non-null   uint8
#  53  srch_co_DoW_Sunday         6387 non-null   uint8
#  54  srch_co_DoW_Thursday       6387 non-null   uint8
#  55  srch_co_DoW_Tuesday        6387 non-null   uint8
#  56  srch_co_DoW_Wednesday      6387 non-null   uint8
#  57  hotel_cluster              6387 non-null   category
# dtypes: category(7), float64(1), int64(9), int8(3), object(4), timedelta64[ns](1), uint8(33)
# memory usage: 1.3+ MB

# %%
# Change category dtype to int64
catList = ranDF.select_dtypes(include=['category']).columns.tolist()
change_dtype(catList, 'int64', ranDF)

# Convert length of stay to integer
ranDF['length_of_stay'] = pd.to_numeric(ranDF['length_of_stay'].dt.days, downcast='integer')

# %% [markdown]
# #### Get features that correlate with the target variable

# %%
# Look at correlations
dfCorr = ranDF.corr()
dfCorr
# Out:
#                            site_name_2  posa_continent_3  \
# site_name_2                   1.000000          0.558708
# posa_continent_3              0.558708          1.000000
# user_location_country_66      0.912264          0.506466
# user_location_region         -0.040131         -0.216411
# user_location_city           -0.063070         -0.007458
# orig_destination_distance    -0.135184         -0.167025
# is_mobile                     0.027451          0.019485
# is_package                   -0.019912         -0.043352
# channel                      -0.030762          0.047875
# length_of_stay               -0.094973         -0.099106
# srch_adults_cnt              -0.025545         -0.014683
# srch_children_cnt             0.010813          0.019457
# srch_rm_cnt                  -0.002000         -0.014972
# srch_destination_id          -0.021817          0.001176
# srch_destination_type_id     -0.015623          0.028366
# is_booking                    0.001895          0.005834
# cnt                          -0.013890         -0.000179
# hotel_continent              -0.156079         -0.223295
# hotel_country                 0.275072          0.233950
# hotel_market                  0.036843          0.005802
# date_time_DoW_Friday         -0.001584         -0.011846
# date_time_DoW_Monday          0.001103          0.012637
# date_time_DoW_Saturday        0.000117          0.010355
# date_time_DoW_Sunday          0.019066          0.022115
# date_time_DoW_Thursday       -0.023049         -0.005139
# date_time_DoW_Tuesday        -0.008431         -0.021018
# date_time_DoW_Wednesday       0.013281         -0.004502
# date_time_MoY_April           0.010615          0.025039
# date_time_MoY_August         -0.025942         -0.031039
# date_time_MoY_December       -0.004605         -0.009954
# date_time_MoY_February        0.000766          0.021001
# date_time_MoY_January        -0.009448          0.011780
# date_time_MoY_July            0.006465          0.005087
# date_time_MoY_June            0.034560          0.037150
# date_time_MoY_March           0.002192          0.005388
# date_time_MoY_May             0.012392          0.008775
# date_time_MoY_November       -0.018948         -0.030377
# date_time_MoY_October        -0.020000         -0.031910
# date_time_MoY_September       0.012835          0.002970
# srch_ci_DoW_Friday            0.034147          0.029932
# srch_ci_DoW_Monday           -0.010874         -0.016707
# srch_ci_DoW_Saturday          0.012333          0.008316
# srch_ci_DoW_Sunday           -0.030654         -0.021313
# srch_ci_DoW_Thursday          0.002244         -0.025628
# srch_ci_DoW_Tuesday          -0.004391          0.004590
# srch_ci_DoW_Wednesday        -0.013539          0.014029
# srch_co_DoW_Friday           -0.011621         -0.024307
# srch_co_DoW_Monday           -0.013935          0.005571
# srch_co_DoW_Saturday          0.013412          0.006342
# srch_co_DoW_Sunday            0.041519          0.015176
# srch_co_DoW_Thursday         -0.013425          0.005746
# srch_co_DoW_Tuesday          -0.012943         -0.010535
# srch_co_DoW_Wednesday        -0.015983         -0.002856
# hotel_cluster                 0.023450          0.010242
#
#                            user_location_country_66  user_location_region  \
# site_name_2                                0.912264             -0.040131
# posa_continent_3                           0.506466             -0.216411
# user_location_country_66                   1.000000             -0.082321
# user_location_region                      -0.082321              1.000000
# user_location_city                        -0.083420              0.139945
# orig_destination_distance                 -0.149413              0.036289
# is_mobile                                  0.037097             -0.005637
# is_package                                -0.020652              0.035384
# channel                                   -0.041868             -0.041227
# length_of_stay                            -0.095226              0.014451
# srch_adults_cnt                           -0.028015              0.025098
# srch_children_cnt                          0.007653              0.006414
# srch_rm_cnt                                0.002098              0.019485
# srch_destination_id                       -0.010961              0.002511
# srch_destination_type_id                  -0.005220             -0.023007
# is_booking                                 0.004481             -0.018731
# cnt                                       -0.015167             -0.000019
# hotel_continent                           -0.183909              0.022648
# hotel_country                              0.299744             -0.056550
# hotel_market                               0.040963              0.014622
# date_time_DoW_Friday                       0.000775             -0.001486
# date_time_DoW_Monday                       0.004673             -0.007313
# date_time_DoW_Saturday                    -0.001831              0.020139
# date_time_DoW_Sunday                       0.015838             -0.002511
# date_time_DoW_Thursday                    -0.028147             -0.010215
# date_time_DoW_Tuesday                      0.001341              0.006347
# date_time_DoW_Wednesday                    0.007132             -0.002984
# date_time_MoY_April                        0.005871             -0.019227
# date_time_MoY_August                      -0.015079              0.010865
# date_time_MoY_December                    -0.004926              0.015105
# date_time_MoY_February                     0.003079             -0.021947
# date_time_MoY_January                     -0.009067              0.016433
# date_time_MoY_July                         0.006263             -0.013515
# date_time_MoY_June                         0.031908             -0.001117
# date_time_MoY_March                        0.000457              0.006813
# date_time_MoY_May                          0.010773              0.000524
# date_time_MoY_November                    -0.018529              0.005421
# date_time_MoY_October                     -0.016597              0.005441
# date_time_MoY_September                    0.006290             -0.006867
# srch_ci_DoW_Friday                         0.038236              0.008461
# srch_ci_DoW_Monday                        -0.012384              0.010609
# srch_ci_DoW_Saturday                       0.012583              0.015768
# srch_ci_DoW_Sunday                        -0.028348              0.004352
# srch_ci_DoW_Thursday                      -0.006785              0.009078
# srch_ci_DoW_Tuesday                       -0.000857             -0.026305
# srch_ci_DoW_Wednesday                     -0.013212             -0.028280
# srch_co_DoW_Friday                        -0.013258             -0.005994
# srch_co_DoW_Monday                        -0.019136             -0.012599
# srch_co_DoW_Saturday                       0.016641             -0.006540
# srch_co_DoW_Sunday                         0.045390              0.023871
# srch_co_DoW_Thursday                      -0.011511              0.004883
# srch_co_DoW_Tuesday                       -0.011320              0.018298
# srch_co_DoW_Wednesday                     -0.020797             -0.026670
# hotel_cluster                              0.011272              0.019475
#
#                            user_location_city  orig_destination_distance  \
# site_name_2                         -0.063070                  -0.135184
# posa_continent_3                    -0.007458                  -0.167025
# user_location_country_66            -0.083420                  -0.149413
# user_location_region                 0.139945                   0.036289
# user_location_city                   1.000000                   0.034973
# orig_destination_distance            0.034973                   1.000000
# is_mobile                            0.002974                  -0.075491
# is_package                           0.000950                   0.032096
# channel                             -0.007826                   0.002370
# length_of_stay                       0.010460                   0.209500
# srch_adults_cnt                      0.011244                  -0.017252
# srch_children_cnt                   -0.030176                  -0.049795
# srch_rm_cnt                         -0.020455                  -0.010428
# srch_destination_id                  0.006998                  -0.010204
# srch_destination_type_id             0.005895                  -0.042029
# is_booking                          -0.017423                  -0.031562
# cnt                                 -0.016748                   0.013139
# hotel_continent                      0.010733                   0.420228
# hotel_country                       -0.018186                  -0.488321
# hotel_market                         0.010158                  -0.076000
# date_time_DoW_Friday                -0.014645                  -0.025623
# date_time_DoW_Monday                 0.004566                  -0.011899
# date_time_DoW_Saturday               0.011358                   0.007376
# date_time_DoW_Sunday                 0.010899                   0.008182
# date_time_DoW_Thursday               0.009340                  -0.003373
# date_time_DoW_Tuesday               -0.000610                   0.015285
# date_time_DoW_Wednesday             -0.018979                   0.009067
# date_time_MoY_April                  0.009344                   0.029429
# date_time_MoY_August                 0.021010                  -0.013496
# date_time_MoY_December               0.000149                  -0.008815
# date_time_MoY_February               0.021608                  -0.001240
# date_time_MoY_January               -0.003916                   0.031534
# date_time_MoY_July                   0.003874                  -0.038445
# date_time_MoY_June                  -0.000096                  -0.031370
# date_time_MoY_March                  0.005874                   0.018685
# date_time_MoY_May                   -0.017171                   0.003235
# date_time_MoY_November              -0.012540                   0.020877
# date_time_MoY_October               -0.015499                   0.005710
# date_time_MoY_September             -0.009180                  -0.000941
# srch_ci_DoW_Friday                   0.008456                  -0.087368
# srch_ci_DoW_Monday                   0.018432                   0.053754
# srch_ci_DoW_Saturday                -0.025593                  -0.030433
# srch_ci_DoW_Sunday                   0.014777                   0.030680
# srch_ci_DoW_Thursday                 0.008229                  -0.002616
# srch_ci_DoW_Tuesday                 -0.015840                   0.049817
# srch_ci_DoW_Wednesday               -0.007583                   0.016757
# srch_co_DoW_Friday                   0.001624                   0.035487
# srch_co_DoW_Monday                  -0.002156                   0.004397
# srch_co_DoW_Saturday                 0.002574                  -0.018192
# srch_co_DoW_Sunday                   0.017746                  -0.123386
# srch_co_DoW_Thursday                -0.025563                   0.036937
# srch_co_DoW_Tuesday                 -0.012276                   0.049365
# srch_co_DoW_Wednesday                0.012043                   0.054764
# hotel_cluster                        0.002966                  -0.000488
#
#                            is_mobile  is_package   channel  length_of_stay  \
# site_name_2                 0.027451   -0.019912 -0.030762       -0.094973
# posa_continent_3            0.019485   -0.043352  0.047875       -0.099106
# user_location_country_66    0.037097   -0.020652 -0.041868       -0.095226
# user_location_region       -0.005637    0.035384 -0.041227        0.014451
# user_location_city          0.002974    0.000950 -0.007826        0.010460
# orig_destination_distance  -0.075491    0.032096  0.002370        0.209500
# is_mobile                   1.000000    0.038366 -0.030484       -0.006110
# is_package                  0.038366    1.000000 -0.004370        0.356850
# channel                    -0.030484   -0.004370  1.000000       -0.003667
# length_of_stay             -0.006110    0.356850 -0.003667        1.000000
# srch_adults_cnt             0.027325   -0.022197 -0.026924       -0.002361
# srch_children_cnt           0.014982   -0.050429 -0.002693        0.033758
# srch_rm_cnt                -0.005826   -0.032350  0.000124       -0.026165
# srch_destination_id        -0.001437   -0.147782  0.019916       -0.101537
# srch_destination_type_id   -0.004551   -0.212691  0.033152       -0.123296
# is_booking                 -0.026517   -0.090088  0.016881       -0.122667
# cnt                        -0.003492    0.131981  0.005494        0.037756
# hotel_continent            -0.029790    0.138221 -0.000201        0.179381
# hotel_country               0.012726   -0.189129 -0.006663       -0.223145
# hotel_market                0.022924   -0.031781  0.000711       -0.028715
# date_time_DoW_Friday       -0.008101   -0.009042  0.010041       -0.025592
# date_time_DoW_Monday       -0.035886   -0.007278  0.010012       -0.003347
# date_time_DoW_Saturday      0.052310    0.006193  0.004398        0.003509
# date_time_DoW_Sunday        0.030675    0.008296 -0.010456        0.017427
# date_time_DoW_Thursday     -0.020261    0.009486  0.007660        0.017505
# date_time_DoW_Tuesday      -0.009175   -0.009419  0.003891       -0.003676
# date_time_DoW_Wednesday    -0.000897    0.003175 -0.024444       -0.005101
# date_time_MoY_April        -0.022828   -0.014784  0.020426       -0.001433
# date_time_MoY_August        0.028478   -0.014055 -0.007676       -0.014344
# date_time_MoY_December      0.018725    0.002918 -0.027118        0.013049
# date_time_MoY_February     -0.008472    0.011376  0.011054        0.008580
# date_time_MoY_January      -0.010698    0.024053  0.016934        0.028447
# date_time_MoY_July          0.039445   -0.010556 -0.002059       -0.029359
# date_time_MoY_June         -0.026625   -0.037313 -0.016208       -0.034981
# date_time_MoY_March        -0.045185    0.023456  0.016818        0.012395
# date_time_MoY_May          -0.002674   -0.001865  0.014710       -0.005204
# date_time_MoY_November      0.014888    0.012174 -0.016709        0.010073
# date_time_MoY_October      -0.015234   -0.000169  0.000030        0.018959
# date_time_MoY_September     0.015388    0.014817  0.001597        0.005070
# srch_ci_DoW_Friday         -0.009709   -0.011628  0.002699       -0.047066
# srch_ci_DoW_Monday         -0.017519   -0.044282  0.019089        0.030189
# srch_ci_DoW_Saturday        0.017634   -0.038515 -0.021784       -0.037846
# srch_ci_DoW_Sunday         -0.003442    0.008652 -0.006061        0.047305
# srch_ci_DoW_Thursday       -0.005546    0.049760  0.013402       -0.000551
# srch_ci_DoW_Tuesday         0.008646   -0.000924 -0.005076       -0.004337
# srch_ci_DoW_Wednesday       0.009902    0.039720 -0.000518        0.029596
# srch_co_DoW_Friday          0.015237    0.035305  0.022387        0.052010
# srch_co_DoW_Monday          0.003807   -0.021424  0.009319       -0.002161
# srch_co_DoW_Saturday       -0.029054    0.035812 -0.011877        0.025330
# srch_co_DoW_Sunday          0.012045   -0.068337 -0.024742       -0.105777
# srch_co_DoW_Thursday        0.010870    0.042099 -0.001531        0.020315
# srch_co_DoW_Tuesday         0.009621   -0.012044  0.004785        0.025176
# srch_co_DoW_Wednesday      -0.023667    0.005035  0.008839        0.012677
# hotel_cluster              -0.001317    0.045512 -0.003455        0.050179
#
#                            ...  srch_ci_DoW_Tuesday  srch_ci_DoW_Wednesday  \
# site_name_2                ...            -0.004391              -0.013539
# posa_continent_3           ...             0.004590               0.014029
# user_location_country_66   ...            -0.000857              -0.013212
# user_location_region       ...            -0.026305              -0.028280
# user_location_city         ...            -0.015840              -0.007583
# orig_destination_distance  ...             0.049817               0.016757
# is_mobile                  ...             0.008646               0.009902
# is_package                 ...            -0.000924               0.039720
# channel                    ...            -0.005076              -0.000518
# length_of_stay             ...            -0.004337               0.029596
# srch_adults_cnt            ...            -0.026047               0.001519
# srch_children_cnt          ...            -0.039611              -0.009962
# srch_rm_cnt                ...             0.000913               0.014506
# srch_destination_id        ...            -0.003074              -0.016389
# srch_destination_type_id   ...             0.009199              -0.007987
# is_booking                 ...             0.011542               0.011053
# cnt                        ...            -0.006152               0.001381
# hotel_continent            ...             0.015543               0.016614
# hotel_country              ...            -0.019603              -0.011566
# hotel_market               ...            -0.001479               0.003735
# date_time_DoW_Friday       ...            -0.005666               0.001689
# date_time_DoW_Monday       ...             0.006097               0.007979
# date_time_DoW_Saturday     ...            -0.024201              -0.022160
# date_time_DoW_Sunday       ...             0.014329               0.005877
# date_time_DoW_Thursday     ...            -0.011273              -0.034777
# date_time_DoW_Tuesday      ...             0.036916               0.025406
# date_time_DoW_Wednesday    ...            -0.020001               0.011256
# date_time_MoY_April        ...            -0.006741               0.005719
# date_time_MoY_August       ...            -0.011502               0.000486
# date_time_MoY_December     ...             0.033996               0.018196
# date_time_MoY_February     ...            -0.009366               0.014609
# date_time_MoY_January      ...            -0.011592               0.015625
# date_time_MoY_July         ...            -0.003346              -0.004105
# date_time_MoY_June         ...             0.019178               0.000308
# date_time_MoY_March        ...            -0.004039              -0.031157
# date_time_MoY_May          ...             0.007460              -0.007350
# date_time_MoY_November     ...             0.004969              -0.009216
# date_time_MoY_October      ...            -0.009356              -0.001822
# date_time_MoY_September    ...            -0.014710               0.003828
# srch_ci_DoW_Friday         ...            -0.173801              -0.197098
# srch_ci_DoW_Monday         ...            -0.122682              -0.139127
# srch_ci_DoW_Saturday       ...            -0.156025              -0.176939
# srch_ci_DoW_Sunday         ...            -0.125756              -0.142612
# srch_ci_DoW_Thursday       ...            -0.141400              -0.160354
# srch_ci_DoW_Tuesday        ...             1.000000              -0.130250
# srch_ci_DoW_Wednesday      ...            -0.130250               1.000000
# srch_co_DoW_Friday         ...             0.031842               0.059683
# srch_co_DoW_Monday         ...            -0.096668              -0.060059
# srch_co_DoW_Saturday       ...            -0.032813               0.037459
# srch_co_DoW_Sunday         ...            -0.112516              -0.050518
# srch_co_DoW_Thursday       ...             0.081051               0.162418
# srch_co_DoW_Tuesday        ...            -0.047057              -0.065251
# srch_co_DoW_Wednesday      ...             0.221104              -0.072219
# hotel_cluster              ...            -0.007903               0.005478
#
#                            srch_co_DoW_Friday  srch_co_DoW_Monday  \
# site_name_2                         -0.011621           -0.013935
# posa_continent_3                    -0.024307            0.005571
# user_location_country_66            -0.013258           -0.019136
# user_location_region                -0.005994           -0.012599
# user_location_city                   0.001624           -0.002156
# orig_destination_distance            0.035487            0.004397
# is_mobile                            0.015237            0.003807
# is_package                           0.035305           -0.021424
# channel                              0.022387            0.009319
# length_of_stay                       0.052010           -0.002161
# srch_adults_cnt                     -0.002099            0.004496
# srch_children_cnt                   -0.016478           -0.007873
# srch_rm_cnt                          0.010749           -0.017233
# srch_destination_id                  0.019197            0.004602
# srch_destination_type_id             0.006192            0.009987
# is_booking                           0.019426           -0.048076
# cnt                                  0.010434           -0.004725
# hotel_continent                      0.021248            0.009457
# hotel_country                       -0.044381            0.010218
# hotel_market                        -0.011366           -0.010281
# date_time_DoW_Friday                -0.009316            0.012239
# date_time_DoW_Monday                -0.013161            0.014173
# date_time_DoW_Saturday              -0.013859            0.016632
# date_time_DoW_Sunday                -0.002416            0.005545
# date_time_DoW_Thursday               0.026108           -0.002858
# date_time_DoW_Tuesday                0.005493           -0.021748
# date_time_DoW_Wednesday              0.005182           -0.019577
# date_time_MoY_April                  0.014892           -0.008909
# date_time_MoY_August                -0.015283            0.027220
# date_time_MoY_December               0.016039           -0.019394
# date_time_MoY_February              -0.013421            0.011319
# date_time_MoY_January               -0.000228            0.019568
# date_time_MoY_July                  -0.009163           -0.003568
# date_time_MoY_June                   0.019927           -0.022749
# date_time_MoY_March                 -0.023518            0.005841
# date_time_MoY_May                   -0.001925            0.019407
# date_time_MoY_November               0.007280           -0.014382
# date_time_MoY_October                0.024493           -0.034091
# date_time_MoY_September             -0.021478            0.027150
# srch_ci_DoW_Friday                  -0.102378            0.023101
# srch_ci_DoW_Monday                   0.024686           -0.084330
# srch_ci_DoW_Saturday                -0.104348            0.047449
# srch_ci_DoW_Sunday                  -0.030132            0.140357
# srch_ci_DoW_Thursday                 0.150466            0.009299
# srch_ci_DoW_Tuesday                  0.031842           -0.096668
# srch_ci_DoW_Wednesday                0.059683           -0.060059
# srch_co_DoW_Friday                   1.000000           -0.158960
# srch_co_DoW_Monday                  -0.158960            1.000000
# srch_co_DoW_Saturday                -0.166238           -0.173311
# srch_co_DoW_Sunday                  -0.212937           -0.221997
# srch_co_DoW_Thursday                -0.141676           -0.147704
# srch_co_DoW_Tuesday                 -0.137543           -0.143396
# srch_co_DoW_Wednesday               -0.141568           -0.147592
# hotel_cluster                        0.010679           -0.019143
#
#                            srch_co_DoW_Saturday  srch_co_DoW_Sunday  \
# site_name_2                            0.013412            0.041519
# posa_continent_3                       0.006342            0.015176
# user_location_country_66               0.016641            0.045390
# user_location_region                  -0.006540            0.023871
# user_location_city                     0.002574            0.017746
# orig_destination_distance             -0.018192           -0.123386
# is_mobile                             -0.029054            0.012045
# is_package                             0.035812           -0.068337
# channel                               -0.011877           -0.024742
# length_of_stay                         0.025330           -0.105777
# srch_adults_cnt                        0.009048            0.029692
# srch_children_cnt                      0.012232            0.032838
# srch_rm_cnt                            0.001364            0.017112
# srch_destination_id                    0.001425            0.005991
# srch_destination_type_id              -0.021284            0.011099
# is_booking                            -0.008848           -0.001271
# cnt                                   -0.000737            0.002752
# hotel_continent                        0.000278           -0.090911
# hotel_country                         -0.000164            0.107152
# hotel_market                           0.021311            0.003318
# date_time_DoW_Friday                   0.006324            0.015111
# date_time_DoW_Monday                  -0.009373           -0.003955
# date_time_DoW_Saturday                -0.007379           -0.002169
# date_time_DoW_Sunday                   0.020595           -0.029383
# date_time_DoW_Thursday                -0.005563            0.012413
# date_time_DoW_Tuesday                 -0.004859           -0.013227
# date_time_DoW_Wednesday                0.001316            0.020321
# date_time_MoY_April                   -0.017548            0.008444
# date_time_MoY_August                  -0.004232           -0.008362
# date_time_MoY_December                -0.002775           -0.025399
# date_time_MoY_February                 0.007767           -0.012548
# date_time_MoY_January                  0.007977           -0.003615
# date_time_MoY_July                     0.001819            0.011100
# date_time_MoY_June                    -0.010181           -0.007786
# date_time_MoY_March                   -0.009909            0.018524
# date_time_MoY_May                      0.001564           -0.001431
# date_time_MoY_November                 0.005685            0.006020
# date_time_MoY_October                  0.014191            0.025296
# date_time_MoY_September                0.007230           -0.011888
# srch_ci_DoW_Friday                     0.172174            0.132231
# srch_ci_DoW_Monday                    -0.069960           -0.156673
# srch_ci_DoW_Saturday                  -0.090789            0.219615
# srch_ci_DoW_Sunday                    -0.082055           -0.142966
# srch_ci_DoW_Thursday                   0.031411            0.030327
# srch_ci_DoW_Tuesday                   -0.032813           -0.112516
# srch_ci_DoW_Wednesday                  0.037459           -0.050518
# srch_co_DoW_Friday                    -0.166238           -0.212937
# srch_co_DoW_Monday                    -0.173311           -0.221997
# srch_co_DoW_Saturday                   1.000000           -0.232162
# srch_co_DoW_Sunday                    -0.232162            1.000000
# srch_co_DoW_Thursday                  -0.154467           -0.197859
# srch_co_DoW_Tuesday                   -0.149961           -0.192088
# srch_co_DoW_Wednesday                 -0.154349           -0.197709
# hotel_cluster                         -0.020843            0.015915
#
#                            srch_co_DoW_Thursday  srch_co_DoW_Tuesday  \
# site_name_2                           -0.013425            -0.012943
# posa_continent_3                       0.005746            -0.010535
# user_location_country_66              -0.011511            -0.011320
# user_location_region                   0.004883             0.018298
# user_location_city                    -0.025563            -0.012276
# orig_destination_distance              0.036937             0.049365
# is_mobile                              0.010870             0.009621
# is_package                             0.042099            -0.012044
# channel                               -0.001531             0.004785
# length_of_stay                         0.020315             0.025176
# srch_adults_cnt                       -0.012168            -0.001543
# srch_children_cnt                      0.002321            -0.015567
# srch_rm_cnt                            0.010522            -0.003481
# srch_destination_id                   -0.030068             0.005904
# srch_destination_type_id              -0.023723             0.016235
# is_booking                             0.010802             0.020391
# cnt                                   -0.006472             0.015972
# hotel_continent                        0.027173             0.011568
# hotel_country                         -0.050139            -0.009977
# hotel_market                           0.021813            -0.013106
# date_time_DoW_Friday                   0.000549             0.003383
# date_time_DoW_Monday                  -0.000255             0.017559
# date_time_DoW_Saturday                 0.002914             0.003301
# date_time_DoW_Sunday                   0.006382            -0.001093
# date_time_DoW_Thursday                -0.031789             0.000950
# date_time_DoW_Tuesday                  0.022919            -0.008171
# date_time_DoW_Wednesday               -0.001607            -0.014897
# date_time_MoY_April                   -0.020076             0.001928
# date_time_MoY_August                   0.000731             0.013756
# date_time_MoY_December                 0.025136            -0.006706
# date_time_MoY_February                -0.009459             0.017585
# date_time_MoY_January                 -0.010597            -0.013940
# date_time_MoY_July                    -0.000993             0.018596
# date_time_MoY_June                     0.007069            -0.009895
# date_time_MoY_March                    0.004197            -0.005132
# date_time_MoY_May                     -0.008806            -0.010728
# date_time_MoY_November                 0.031735            -0.021926
# date_time_MoY_October                 -0.027386            -0.006579
# date_time_MoY_September                0.001934             0.020000
# srch_ci_DoW_Friday                    -0.107900            -0.072360
# srch_ci_DoW_Monday                     0.062427             0.204999
# srch_ci_DoW_Saturday                  -0.077055             0.002243
# srch_ci_DoW_Sunday                     0.018082             0.051588
# srch_ci_DoW_Thursday                  -0.089546            -0.049955
# srch_ci_DoW_Tuesday                    0.081051            -0.047057
# srch_ci_DoW_Wednesday                  0.162418            -0.065251
# srch_co_DoW_Friday                    -0.141676            -0.137543
# srch_co_DoW_Monday                    -0.147704            -0.143396
# srch_co_DoW_Saturday                  -0.154467            -0.149961
# srch_co_DoW_Sunday                    -0.197859            -0.192088
# srch_co_DoW_Thursday                   1.000000            -0.127804
# srch_co_DoW_Tuesday                   -0.127804             1.000000
# srch_co_DoW_Wednesday                 -0.131544            -0.127707
# hotel_cluster                          0.002155            -0.003811
#
#                            srch_co_DoW_Wednesday  hotel_cluster
# site_name_2                            -0.015983       0.023450
# posa_continent_3                       -0.002856       0.010242
# user_location_country_66               -0.020797       0.011272
# user_location_region                   -0.026670       0.019475
# user_location_city                      0.012043       0.002966
# orig_destination_distance               0.054764      -0.000488
# is_mobile                              -0.023667      -0.001317
# is_package                              0.005035       0.045512
# channel                                 0.008839      -0.003455
# length_of_stay                          0.012677       0.050179
# srch_adults_cnt                        -0.038121       0.026269
# srch_children_cnt                      -0.017928       0.008609
# srch_rm_cnt                            -0.023689      -0.006924
# srch_destination_id                    -0.010465      -0.001218
# srch_destination_type_id               -0.000190      -0.033595
# is_booking                              0.012724      -0.018244
# cnt                                    -0.017809       0.014034
# hotel_continent                         0.047664       0.001680
# hotel_country                          -0.044656      -0.035292
# hotel_market                           -0.014108       0.014358
# date_time_DoW_Friday                   -0.034282       0.012268
# date_time_DoW_Monday                   -0.002715      -0.007782
# date_time_DoW_Saturday                  0.001530      -0.012606
# date_time_DoW_Sunday                    0.006574       0.010153
# date_time_DoW_Thursday                 -0.003639      -0.004125
# date_time_DoW_Tuesday                   0.025768      -0.008719
# date_time_DoW_Wednesday                 0.003897       0.010794
# date_time_MoY_April                     0.020826      -0.005476
# date_time_MoY_August                   -0.011962       0.016285
# date_time_MoY_December                  0.022023      -0.014782
# date_time_MoY_February                  0.001847      -0.010822
# date_time_MoY_January                  -0.001078      -0.005498
# date_time_MoY_July                     -0.020222      -0.006906
# date_time_MoY_June                      0.027990      -0.002399
# date_time_MoY_March                     0.006167       0.009724
# date_time_MoY_May                       0.000306       0.011133
# date_time_MoY_November                 -0.016626      -0.002436
# date_time_MoY_October                  -0.004053      -0.002015
# date_time_MoY_September                -0.020911       0.009418
# srch_ci_DoW_Friday                     -0.105306       0.018105
# srch_ci_DoW_Monday                      0.087067      -0.012174
# srch_ci_DoW_Saturday                   -0.052436      -0.007325
# srch_ci_DoW_Sunday                      0.090182       0.012372
# srch_ci_DoW_Thursday                   -0.105894      -0.011651
# srch_ci_DoW_Tuesday                     0.221104      -0.007903
# srch_ci_DoW_Wednesday                  -0.072219       0.005478
# srch_co_DoW_Friday                     -0.141568       0.010679
# srch_co_DoW_Monday                     -0.147592      -0.019143
# srch_co_DoW_Saturday                   -0.154349      -0.020843
# srch_co_DoW_Sunday                     -0.197709       0.015915
# srch_co_DoW_Thursday                   -0.131544       0.002155
# srch_co_DoW_Tuesday                    -0.127707      -0.003811
# srch_co_DoW_Wednesday                   1.000000       0.013707
# hotel_cluster                           0.013707       1.000000
#
# [54 rows x 54 columns]

# %% [markdown]
# Correlations are really low. Get a list of the most highly correlated.

# %%
# Get a list of variables with > 0.01 correlation
hiCorr = dfCorr['hotel_cluster'][abs(dfCorr['hotel_cluster']) > 0.01]
# Convert to a sorted list by highest correlation
hiCorrList = abs(hiCorr).sort_values(ascending=False).index.to_list()
# Remove target variable from list
hiCorrList = hiCorrList[1:]

# %% [markdown]
# #### Get a list of best variables using Feature Selection

# %%
# Load libraries
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Select numerical columns

# %%
# Reorder / select columns
numCols = ['site_name_2', 'posa_continent_3',
       'user_location_country_66', 'user_location_region',
       'user_location_city', 'orig_destination_distance', 'is_mobile',
       'is_package', 'channel', 'length_of_stay',
       'srch_adults_cnt', 'srch_children_cnt', 'srch_rm_cnt',
       'srch_destination_id', 'srch_destination_type_id', 'is_booking', 'cnt',
       'hotel_continent', 'hotel_country', 'hotel_market',
       'date_time_DoW_Friday', 'date_time_DoW_Monday',
       'date_time_DoW_Saturday', 'date_time_DoW_Sunday',
       'date_time_DoW_Thursday', 'date_time_DoW_Tuesday',
       'date_time_DoW_Wednesday', 'date_time_MoY_April',
       'date_time_MoY_August', 'date_time_MoY_December',
       'date_time_MoY_February', 'date_time_MoY_January', 'date_time_MoY_July',
       'date_time_MoY_June', 'date_time_MoY_March', 'date_time_MoY_May',
       'date_time_MoY_November', 'date_time_MoY_October',
       'date_time_MoY_September', 'srch_ci_DoW_Friday', 'srch_ci_DoW_Monday',
       'srch_ci_DoW_Saturday', 'srch_ci_DoW_Sunday', 'srch_ci_DoW_Thursday',
       'srch_ci_DoW_Tuesday', 'srch_ci_DoW_Wednesday', 'srch_co_DoW_Friday',
       'srch_co_DoW_Monday', 'srch_co_DoW_Saturday', 'srch_co_DoW_Sunday',
       'srch_co_DoW_Thursday', 'srch_co_DoW_Tuesday', 'srch_co_DoW_Wednesday',
       'hotel_cluster']
numDF = ranDF[numCols].copy()

# %% [markdown]
# Split data for feature selection:

# %%
# Set up features target sets
X = numDF[numDF.columns[:-1]]
y = numDF.hotel_cluster

# Encode the target variables
le = LabelEncoder()
y = le.fit_transform(y)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.3, 
                                                    random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train) 
X_test  = scaler.transform(X_test)

# %% [markdown]
# #### Feature Selection

# %%
# Feature selection using F-statistic
from sklearn.feature_selection import f_classif
f = f_classif(X_train, y_train)[0]

# %%
# Feature selection using mutual information
from sklearn.feature_selection import mutual_info_classif
mi = mutual_info_classif(X_train, y_train)

# %%
# Feature selection using logistic regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=500).fit(X_train, y_train)

# %%
# Feature selection using light gbm
from lightgbm import LGBMClassifier
lgbm = LGBMClassifier(
    objective = 'multiclass',
    metric = 'multi_logloss',
    importance_type = 'gain'
).fit(X_train, y_train)

# %% [markdown]
# Store Results

# %%
# Create DF to store feature ranking info
ranking = pd.DataFrame(index = range(X_train.shape[1]))

# Store ranking info for each feature from each method
ranking['feat'] = X.columns
ranking['f'] = pd.Series(f, index = ranking.index).fillna(0).rank(ascending = False)
ranking['mi'] = pd.Series(mi, index = ranking.index).fillna(0).rank(ascending = False)
ranking['logreg'] = pd.Series(np.abs(logreg.coef_).mean(axis = 0), index = ranking.index).rank(ascending = False)
ranking['lightgbm'] = pd.Series(lgbm.feature_importances_, index = ranking.index).rank(ascending = False)
# ranking['mrmr'] = pd.Series(list(range(1, len(mrmr) + 1)) + [X_train.shape[1]] * (X_train.shape[1] - len(mrmr)), index = mrmr + list(set(ranking.index) - set(mrmr))).sort_index()

ranking = ranking.replace(to_replace = ranking.max(), value = X_train.shape[1])
ranking.to_csv('ranking.csv', index = False)

# %% [markdown]
# Compare

# %%
# Sum the rankings across methods
ranking['total'] = ranking.sum(axis=1)
# Sort by sum to get an overall idea of the most/least useful features
ranking.sort_values('total')
# Out:
# C:\Users\micha\AppData\Local\Temp/ipykernel_11592/740563463.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ranking['total'] = ranking.sum(axis=1)
#                          feat     f    mi  logreg  lightgbm  total
# 5   orig_destination_distance   3.0   5.0     3.0       2.0   13.0
# 17            hotel_continent   2.0   3.0     2.0       6.0   13.0
# 18              hotel_country   1.0   4.0     1.0      13.0   19.0
# 19               hotel_market   8.0   1.0    10.0       1.0   20.0
# 9              length_of_stay   5.0   6.0     7.0       7.0   25.0
# 13        srch_destination_id  10.0   2.0    11.0       3.0   26.0
# 7                  is_package   4.0   8.0     8.0      14.0   34.0
# 14   srch_destination_type_id  11.0   7.0    15.0      10.0   43.0
# 11          srch_children_cnt  18.0  13.0    14.0      12.0   57.0
# 3                          53  19.0  12.0    25.0       5.0   61.0
# 2    user_location_country_66   7.0  11.0     5.0      48.0   71.0
# 1            posa_continent_3   6.0   9.0     6.0      53.0   74.0
# 44        srch_ci_DoW_Tuesday  15.0  10.0    21.0      29.0   75.0
# 15                 is_booking  13.0  15.0    13.0      44.0   85.0
# 10            srch_adults_cnt  26.0  42.0    12.0       9.0   89.0
# 40         srch_ci_DoW_Monday  12.0  34.0    18.0      26.0   90.0
# 0                 site_name_2   9.0  46.0     4.0      37.0   96.0
# 35          date_time_MoY_May  24.0  19.0    19.0      35.0   97.0
# 6                   is_mobile  30.0  32.0    20.0      18.0  100.0
# 16                        cnt  22.0  45.0    24.0      11.0  102.0
# 24     date_time_DoW_Thursday  16.0  35.0    29.0      23.0  103.0
# 29     date_time_MoY_December  23.0  30.0    26.0      25.0  104.0
# 47         srch_co_DoW_Monday  25.0  43.0    28.0      16.0  112.0
# 31      date_time_MoY_January  20.0  26.0    16.0      52.0  114.0
# 26    date_time_DoW_Wednesday  32.0  17.0    43.0      22.0  114.0
# 27        date_time_MoY_April  27.0  25.0    23.0      42.0  117.0
# 34        date_time_MoY_March  43.0  14.0    22.0      40.0  119.0
# 30     date_time_MoY_February  28.0  24.0    17.0      51.0  120.0
# 12                srch_rm_cnt  35.0  29.0     9.0      50.0  123.0
# 46         srch_co_DoW_Friday  17.0  41.0    30.0      36.0  124.0
# 49         srch_co_DoW_Sunday  14.0  49.0    46.0      17.0  126.0
# 42         srch_ci_DoW_Sunday  33.0  21.0    31.0      41.0  126.0
# 4          user_location_city  46.0  39.0    38.0       4.0  127.0
# 20       date_time_DoW_Friday  50.0  18.0    41.0      20.0  129.0
# 39         srch_ci_DoW_Friday  21.0  47.0    48.0      15.0  131.0
# 21       date_time_DoW_Monday  44.0  20.0    50.0      24.0  138.0
# 28       date_time_MoY_August  49.0  16.0    35.0      38.0  138.0
# 32         date_time_MoY_July  40.0  22.0    44.0      33.0  139.0
# 33         date_time_MoY_June  38.0  23.0    33.0      45.0  139.0
# 23       date_time_DoW_Sunday  41.0  27.0    45.0      27.0  140.0
# 22     date_time_DoW_Saturday  39.0  36.0    27.0      39.0  141.0
# 38    date_time_MoY_September  34.0  28.0    36.0      43.0  141.0
# 43       srch_ci_DoW_Thursday  36.0  40.0    47.0      19.0  142.0
# 48       srch_co_DoW_Saturday  37.0  38.0    34.0      34.0  143.0
# 8                     channel  45.0  53.0    39.0       8.0  145.0
# 37      date_time_MoY_October  31.0  51.0    40.0      31.0  153.0
# 52      srch_co_DoW_Wednesday  42.0  48.0    37.0      30.0  157.0
# 41       srch_ci_DoW_Saturday  48.0  31.0    52.0      28.0  159.0
# 25      date_time_DoW_Tuesday  52.0  33.0    53.0      21.0  159.0
# 36     date_time_MoY_November  51.0  37.0    32.0      46.0  166.0
# 50       srch_co_DoW_Thursday  29.0  44.0    51.0      49.0  173.0
# 45      srch_ci_DoW_Wednesday  47.0  50.0    49.0      32.0  178.0
# 51        srch_co_DoW_Tuesday  53.0  52.0    42.0      47.0  194.0

# %%
# Get the highest ranked Features
hiRank = ranking[ranking['total'] <= 110].sort_values('total')

# %%
# Get a list of the highest ranked features
hiRankList = hiRank['feat'].tolist()
# Fix that weird 53 that popped up in there
hiRankList = np.array(hiRankList)
hiRankList = np.where(hiRankList == '53', 'user_location_region', hiRankList)
# Convert array back to list
hiRankList = hiRankList.tolist()

# %%
# Combine top 15 from correlation and features into one list of columns
combined = list(set(hiCorrList[:15]).union(set(hiRankList[:15])))
combined
# Out:
# ['site_name_2',
#  'srch_co_DoW_Sunday',
#  'orig_destination_distance',
#  'srch_children_cnt',
#  'posa_continent_3',
#  'srch_adults_cnt',
#  'is_package',
#  'date_time_MoY_December',
#  'hotel_market',
#  'srch_co_DoW_Monday',
#  'srch_ci_DoW_Tuesday',
#  'hotel_continent',
#  'length_of_stay',
#  'date_time_MoY_August',
#  'hotel_country',
#  'srch_ci_DoW_Friday',
#  'srch_destination_type_id',
#  'srch_destination_id',
#  'srch_co_DoW_Saturday',
#  'user_location_region',
#  'user_location_country_66',
#  'is_booking']

# %% [markdown]
# Run modeling using dataframes with high feature rank, high correlation, and a mix of both:

# %%
# Create a dataframe for use in modeling
# modelDF = ranDF[combined]
modelDF = ranDF[hiRankList]
# modelDF = ranDF[hiCorrList]

# %%
# Save data
modelDF.to_csv('modelDF.csv', index=False)

# %% [markdown]
# ### Split train / test data

# %%
# Set up features target sets
X = modelDF # check back for hicorr?
y = ranDF.hotel_cluster

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.3, 
                                                    random_state=42)

# Standardize Features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train) 
X_test  = scaler.transform(X_test)

# %% [markdown]
# ### Build Baseline Prediction Models

# %%
# Set up dictionary for model results
models_dict = {}

# %% [markdown]
# #### Logistic Regression

# %%
# Load libraries
from sklearn.linear_model import LogisticRegression

# Create classification model
logistic = LogisticRegression(random_state=42, 
                              n_jobs=-1)

# %%
# %%time
# Fit model
models_dict['Logistic'] = logistic.fit(X_train, y_train)
# Out:
# Wall time: 23.5 s

# %% [markdown]
# #### Random Forest

# %%
# Load libraries
from sklearn.ensemble import RandomForestClassifier

# Create classification model
rfclassifier = RandomForestClassifier(random_state=42,
                                      n_jobs=-1)

# %%
# %%time
# Fit model
models_dict['RandomForest'] = rfclassifier.fit(X_train, y_train)
# Out:
# Wall time: 7.11 s

# %% [markdown]
# #### Decision Tree

# %%
# Load libraries
from sklearn.tree import DecisionTreeClassifier

# Create classification model
decisiontree = DecisionTreeClassifier(random_state=42, 
                                      class_weight='balanced')

# %%
# %%time
# Fit model
models_dict['DecisionTree'] = decisiontree.fit(X_train, y_train)
# Out:
# Wall time: 789 ms

# %% [markdown]
# #### AdaBoost

# %%
# Load libraries
from sklearn.ensemble import AdaBoostClassifier

# Create classification model
adaboost = AdaBoostClassifier(random_state=42)

# %%
# %%time
# Fit model
models_dict['AdaBoost'] = adaboost.fit(X_train, y_train)
# Out:
# Wall time: 8.79 s

# %% [markdown]
# #### Support Vector Classifier (SVC)

# %%
# Load libraries
from sklearn.svm import SVC

# Create classification model
svc = SVC(random_state=42)

# %%
# %%time
# Fit model
models_dict['SVC'] = svc.fit(X_train, y_train)
# Out:
# Wall time: 2min 47s

# %% [markdown]
# #### Gaussian Naive Bayes Classifier

# %%
# Load libraries
from sklearn.naive_bayes import GaussianNB

# Create Gaussian naive Bayes object
nBayes = GaussianNB()

# %%
# %%time
# Fit model
models_dict['GaussianNB'] = nBayes.fit(X_train, y_train)
# Out:
# Wall time: 90.3 ms

# %% [markdown]
# #### MLPCClassifier

# %%
# Load libraries
from sklearn.neural_network import MLPClassifier

# Create classification model
mlp = MLPClassifier()

# %%
# %%time
# Fit model
models_dict['MLP'] = mlp.fit(X_train, y_train)
# Out:
# Wall time: 2min 1s
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# #### Compare Accuracies

# %%
# %%time
# Create lists of models and accuracy scores
modelName = []
score = []
for key in models_dict:
    modelName += [key]
    model = models_dict[key]
    value = model.score(X_test, y_test)*100
    score += [round(value, 2)]

# Create DataFrame of results
d = {'Model': modelName, 'Accuracy': score}
results = pd.DataFrame(d).sort_values(by=['Accuracy'], ascending=False)
results
# Out:
# Wall time: 3min 48s
#           Model  Accuracy
# 6           MLP      8.27
# 2  DecisionTree      8.01
# 1  RandomForest      7.92
# 4           SVC      6.93
# 0      Logistic      6.51
# 3      AdaBoost      4.71
# 5    GaussianNB      4.43

# %% [markdown]
# The Decision Tree model performed best with highly correlated variables, all others performed as good or better with highly ranked features, with the mix landing in-between.

# %% [markdown]
# ## Hyperparameter tuning

# %%
# Load libraries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
# Set up dictionary for model results
models_dict = {}

# %% [markdown]
# The following were tuned using initial random sample of 100,000 records:

# %% [markdown]
# #### Gaussian Naive Bayes Classifier

# %%
# Load libraries
from sklearn.naive_bayes import GaussianNB

# Create Gaussian naive Bayes object
nBayes = GaussianNB()

# Get a baseline model
baseline = nBayes.fit(X_train, y_train)

# Create range of candidate hyperparameter values
parameter_space = {
    'var_smoothing': np.logspace(-10, -1, 10),
}
grid = GridSearchCV(nBayes, parameter_space, n_jobs=-1, cv=5)

# %%
# %%time
# Fit models
grid_result = grid.fit(X_train, y_train)
# Out:
# Wall time: 12.9 s

# %%
# Show best parameters
print('Best parameters found:\n', grid_result.best_params_, '\n')
# Get accuracy scores
baseScore = round(baseline.score(X_test, y_test)*100, 2)
score = round(grid_result.score(X_test, y_test)*100, 2)
print(f"Baseline Accuracy:\t{baseScore}")
print(f"Tuned Accuracy:\t\t{score}")
# Out:
# Best parameters found:
#  {'var_smoothing': 0.1}
#
# Baseline Accuracy:	4.89
# Tuned Accuracy:		5.85

# %% [markdown]
# #### Decision Tree

# %%
# Load libraries
from sklearn.tree import DecisionTreeClassifier

# Create decision tree regressor object
decisiontree = DecisionTreeClassifier(random_state=42)

# Get a baseline model
baseline = decisiontree.fit(X_train, y_train)

# Create range of candidate penalty hyperparameter values
parameter_space = {
    'criterion': ['gini', 'entropy'], 
    'splitter': ['best', 'random'],
    'max_depth': [None, 5, 8, 10],
    'min_samples_split': [2, 4, 8],
    'min_samples_leaf': [1, 2, 4],
    'max_leaf_nodes': [30, 100, 300, 1000, None],
    'class_weight': ['balanced', None],
    'max_features': ['sqrt', 'log2', None], 
}
grid = GridSearchCV(decisiontree, parameter_space, verbose=2, n_jobs=-1, cv=5)

# %%
# %%time
# Fit models
grid_result = grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4320 candidates, totalling 21600 fits
# Wall time: 30min 48s

# %%
# Show best parameters
print('Best parameters found:\n', grid_result.best_params_, '\n')
# Get accuracy scores
baseScore = round(baseline.score(X_test, y_test)*100, 2)
score = round(grid_result.score(X_test, y_test)*100, 2)
print(f"Baseline Accuracy:\t{baseScore}")
print(f"Tuned Accuracy:\t\t{score}")
# Out:
# Best parameters found:
#  {'class_weight': None, 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 300, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Baseline Accuracy:	7.86
# Tuned Accuracy:		12.9

# %% [markdown]
# #### AdaBoost

# %%
# Load libraries
from sklearn.ensemble import AdaBoostClassifier

# Create classifier
adaboost = AdaBoostClassifier(random_state=42)

# Get a baseline model
baseline = adaboost.fit(X_train, y_train)

# Create range of candidate penalty hyperparameter values
parameter_space = {
    'n_estimators': [100, 300, 1000, 3000], 
    'learning_rate': [0.1, 1, 10],
    'algorithm': ['SAMME', 'SAMME.R'], 
}
grid = GridSearchCV(adaboost, parameter_space, n_jobs=-1, cv=5)

# %%
# %%time
# Fit models
grid_result = grid.fit(X_train, y_train)
# Out:
# Wall time: 1h 42min 59s

# %%
# Show best parameters
print('Best parameters found:\n', grid_result.best_params_, '\n')
# Get accuracy scores
baseScore = round(baseline.score(X_test, y_test)*100, 2)
score = round(grid_result.score(X_test, y_test)*100, 2)
print(f"Baseline Accuracy:\t{baseScore}")
print(f"Tuned Accuracy:\t\t{score}")
# Out:
# Best parameters found:
#  {'algorithm': 'SAMME', 'learning_rate': 1, 'n_estimators': 1000}
#
# Baseline Accuracy:	4.91
# Tuned Accuracy:		6.1

# %% [markdown]
# Due to limited time, the following were tuned using initial random sample of 10,000 records:

# %% [markdown]
# #### Random Forest

# %%
# Load libraries
from sklearn.ensemble import RandomForestClassifier

# Create classifier
rfc = RandomForestClassifier(random_state=42,
                             n_jobs=-1)

# Get a baseline model
baseline = rfc.fit(X_train, y_train)

# Create range of candidate penalty hyperparameter values
parameter_space = {
    'n_estimators': [30, 100, 300, 1000], 
    'criterion': ['gini', 'entropy'], 
    'max_features': ['sqrt', 'log2', None], 
}
grid = GridSearchCV(rfc, parameter_space, n_jobs=-1, cv=5)

# %%
# %%time
# Fit models
grid_result = grid.fit(X_train, y_train)
# Out:
# Wall time: 15min 4s

# %%
# Show best parameters
print('Best parameters found:\n', grid_result.best_params_, '\n')
# Get accuracy scores
baseScore = round(baseline.score(X_test, y_test)*100, 2)
score = round(grid_result.score(X_test, y_test)*100, 2)
print(f"Baseline Accuracy:\t{baseScore}")
print(f"Tuned Accuracy:\t\t{score}")
# Out:
# Best parameters found:
#  {'criterion': 'entropy', 'max_features': None, 'n_estimators': 1000}
#
# Baseline Accuracy:	6.99
# Tuned Accuracy:		7.41

# %% [markdown]
# #### Linear Regression

# %%
# Load libraries
from sklearn.linear_model import LogisticRegression

# Create logistic regression
logistic = LogisticRegression(random_state=42, 
                              max_iter=300, 
                              multi_class='auto',
                              n_jobs=-1)

# Get a baseline model
baseline = logistic.fit(X_train, y_train)

# Create range of candidate penalty hyperparameter values
parameter_space = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'], 
    'tol': [1e-2, 1e-3, 1e-4],
    'C': np.logspace(0, 2, 3), 
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], 
}
grid = GridSearchCV(logistic, parameter_space, n_jobs=-1, cv=5)

# %%
# %%time
# Fit models
grid_result = grid.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#  0.06689038 0.06689038 0.06689038        nan        nan        nan
#  0.06375839 0.0639821  0.06353468 0.0639821  0.0639821  0.0639821
#  0.0639821  0.0639821  0.0639821  0.06465324 0.06510067 0.06510067
#  0.06308725 0.06375839 0.0639821  0.06219239 0.06375839 0.0639821
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.06152125 0.06152125 0.06152125
#  0.06152125 0.06152125 0.06152125        nan        nan        nan
#  0.06331096 0.06174497 0.06174497 0.06420582 0.06174497 0.06196868
#         nan        nan        nan        nan        nan        nan
#  0.06263982 0.06263982 0.06308725        nan        nan        nan
#  0.06375839 0.06286353 0.06263982 0.06196868 0.06196868 0.06196868
#  0.06196868 0.06174497 0.06174497 0.06286353 0.06286353 0.06286353
#  0.06308725 0.06219239 0.06219239 0.0639821  0.06219239 0.06219239
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.06152125 0.06152125 0.06152125
#  0.06152125 0.06152125 0.06152125        nan        nan        nan
#  0.06331096 0.06174497 0.06174497 0.06420582 0.06174497 0.06196868
#         nan        nan        nan        nan        nan        nan
#  0.06331096 0.06331096 0.06331096        nan        nan        nan
#  0.06442953 0.06196868 0.06196868 0.06174497 0.06174497 0.06174497
#  0.06174497 0.06174497 0.06174497 0.06286353 0.06286353 0.06286353
#  0.06331096 0.06219239 0.06196868 0.06420582 0.06174497 0.06196868
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.06152125 0.06152125 0.06152125
#  0.06152125 0.06152125 0.06152125        nan        nan        nan
#  0.06331096 0.06174497 0.06174497 0.06420582 0.06174497 0.06196868]
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Wall time: 25min 25s

# %%
# Show best parameters
print('Best parameters found:\n', grid_result.best_params_, '\n')
# Get accuracy scores
baseScore = round(baseline.score(X_test, y_test)*100, 2)
score = round(grid_result.score(X_test, y_test)*100, 2)
print(f"Baseline Accuracy:\t{baseScore}")
print(f"Tuned Accuracy:\t\t{score}")
# Out:
# Best parameters found:
#  {'C': 1.0, 'penalty': 'l1', 'solver': 'liblinear', 'tol': 0.001}
#
# Baseline Accuracy:	6.0
# Tuned Accuracy:		6.47

# %% [markdown]
# #### Support Vector Classifier (SVC)

# %%
# Load libraries
from sklearn.svm import SVC

# Create support vector classifier
svc = SVC(random_state=42, 
          max_iter=10000)

# Get a baseline model
baseline = svc.fit(X_train, y_train)

# Create range of candidate penalty hyperparameter values
parameter_space = {
    'C': [1, 3, 10, 30, 100], 
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto'], 
    'shrinking': [True, False], 
    'tol': [1e-3, 1e-4, 1e-5],
    'decision_function_shape': ['ovo', 'ovr'], 
    'break_ties': [True],
}
grid = GridSearchCV(svc, parameter_space, n_jobs=-1, cv=5)

# %%
# %%time
# Fit models
grid_result = grid.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.06420582 0.06442953 0.06420582 0.06442953 0.06442953 0.06442953
#  0.05279642 0.05279642 0.05279642 0.05279642 0.05279642 0.05279642
#  0.0689038  0.0689038  0.0689038  0.0689038  0.0689038  0.0689038
#  0.06442953 0.06420582 0.06420582 0.06442953 0.06420582 0.06420582
#  0.06420582 0.06442953 0.06420582 0.06442953 0.06442953 0.06442953
#  0.05324385 0.05324385 0.05324385 0.05324385 0.05324385 0.05324385
#  0.0689038  0.0689038  0.0689038  0.0689038  0.0689038  0.0689038
#  0.06510067 0.06487696 0.06487696 0.06510067 0.06487696 0.06487696
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.05928412 0.05995526 0.05995526 0.05950783 0.05950783 0.05950783
#  0.05123043 0.05123043 0.05123043 0.05123043 0.05123043 0.05123043
#  0.05592841 0.05592841 0.05592841 0.05592841 0.05592841 0.05592841
#  0.05816555 0.05794183 0.05816555 0.05816555 0.05794183 0.05816555
#  0.05928412 0.05995526 0.05995526 0.05950783 0.05950783 0.05950783
#  0.05055928 0.05055928 0.05055928 0.05055928 0.05055928 0.05055928
#  0.05592841 0.05592841 0.05592841 0.05592841 0.05592841 0.05592841
#  0.05704698 0.05682327 0.05682327 0.05704698 0.05682327 0.05682327
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.06196868 0.06196868 0.06174497 0.06107383 0.06129754 0.06129754
#  0.04451902 0.04451902 0.04451902 0.04451902 0.04451902 0.04451902
#  0.04742729 0.04742729 0.04742729 0.04742729 0.04742729 0.04742729
#  0.05123043 0.05123043 0.05123043 0.05234899 0.05212528 0.05212528
#  0.06196868 0.06196868 0.06174497 0.06107383 0.06129754 0.06129754
#  0.04451902 0.04451902 0.04451902 0.04451902 0.04451902 0.04451902
#  0.04697987 0.04742729 0.04742729 0.04697987 0.04742729 0.04742729
#  0.050783   0.050783   0.050783   0.05100671 0.05100671 0.05100671
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.0590604  0.05883669 0.05794183 0.05928412 0.05928412 0.05928412
#  0.04026846 0.04026846 0.04026846 0.04026846 0.04026846 0.04026846
#  0.0458613  0.0458613  0.0458613  0.0458613  0.0458613  0.0458613
#  0.04675615 0.04720358 0.04697987 0.04563758 0.04563758 0.04541387
#  0.0590604  0.05883669 0.05794183 0.05928412 0.05928412 0.05928412
#  0.04049217 0.04049217 0.04049217 0.04049217 0.04049217 0.04049217
#  0.0458613  0.0458613  0.0458613  0.0458613  0.0458613  0.0458613
#  0.04832215 0.049217   0.04854586 0.04787472 0.04787472 0.04787472
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.05369128 0.05369128 0.05279642 0.05503356 0.05503356 0.05503356
#  0.0393736  0.0393736  0.0393736  0.0393736  0.0393736  0.0393736
#  0.04272931 0.04250559 0.04250559 0.04272931 0.04250559 0.04250559
#  0.04675615 0.04653244 0.04653244 0.04653244 0.04653244 0.04653244
#  0.05369128 0.05369128 0.05279642 0.05503356 0.05503356 0.05503356
#  0.0393736  0.0393736  0.0393736  0.0393736  0.0393736  0.0393736
#  0.04250559 0.04250559 0.04250559 0.04250559 0.04250559 0.04250559
#  0.04653244 0.04653244 0.04675615 0.04630872 0.04630872 0.04630872]
#   warnings.warn(
# Wall time: 1h 7min 13s

# %%
# Show best parameters
print('Best parameters found:\n', grid_result.best_params_, '\n')
# Get accuracy scores
baseScore = round(baseline.score(X_test, y_test)*100, 2)
score = round(grid_result.score(X_test, y_test)*100, 2)
print(f"Baseline Accuracy:\t{baseScore}")
print(f"Tuned Accuracy:\t\t{score}")
# Out:
# Best parameters found:
#  {'C': 1, 'break_ties': True, 'decision_function_shape': 'ovr', 'gamma': 'scale', 'kernel': 'rbf', 'shrinking': True, 'tol': 0.001}
#
# Baseline Accuracy:	6.78
# Tuned Accuracy:		6.83

# %% [markdown]
# #### MLPClassifier

# %%
# Load libraries
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import RandomizedSearchCV
import random as rd
from scipy.stats import uniform, randint

# Create classifier
mlp = MLPClassifier(max_iter=5000)

# Get a baseline model
baseline = mlp.fit(X_train, y_train)

# Create range of candidate hyperparameter values
parameter_space = {
    'hidden_layer_sizes': [(rd.randint(10,100), rd.randint(10,100), rd.randint(10,100))],
    'activation': ['relu', 'tanh', 'identity', 'logistic'], 
    'solver': ['adam', 'lbfgs'], #'sgd'], 
    'alpha': [0.001, 0.0001, 0.00001], #uniform(loc=0, scale=0.0005), 
#     'learning_rate': ['constant', 'adaptive', 'invscaling'], # only when solver='sgd' 
    'learning_rate_init': [0.01, 0.001, 0.0001], 
    'tol': [1e-3, 1e-4, 1e-5],
    'early_stopping': [True], 
#     'beta_1': [0.9, 0.99], 
#     'beta_2': [0.99, 0.999, 0.9999],
    'epsilon': [1e-9, 1e-8, 1e-7],
}
rand = RandomizedSearchCV(mlp, parameter_space, random_state=42, n_iter=500, n_jobs=-1, cv=5)

# %%
# %%time
# Fit models
rand_result = rand.fit(X_train, y_train)
# Out:
# Wall time: 15h 45min 27s

# %%
# Show best parameters
print('Best parameters found:\n', rand_result.best_params_, '\n')
# Get accuracy scores
baseScore = round(baseline.score(X_test, y_test)*100, 2)
score = round(rand_result.score(X_test, y_test)*100, 2)
print(f"Baseline Accuracy:\t{baseScore}")
print(f"Tuned Accuracy:\t\t{score}")
# Out:
# Best parameters found:
#  {'tol': 1e-05, 'solver': 'adam', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (32, 68, 24), 'epsilon': 1e-09, 'early_stopping': True, 'alpha': 1e-05, 'activation': 'logistic'}
#
# Baseline Accuracy:	3.86
# Tuned Accuracy:		6.1

# %% [markdown]
# ## Modeling with Tuned Parameters

# %%
# Set up dictionary for model results
models_dict = {}

# %% [markdown]
# #### Logistic Regression

# %%
# Load libraries
from sklearn.linear_model import LogisticRegression

# Create classification model
logistic = LogisticRegression(C=1.0,
                              penalty='l1',
                              solver='liblinear',
                              tol=0.001,
                              random_state=42, 
                              n_jobs=-1)

# %%
# %%time
# Fit model
models_dict['Logistic'] = logistic.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Wall time: 1.46 s

# %% [markdown]
# #### Random Forest

# %%
# Load libraries
from sklearn.ensemble import RandomForestClassifier

# Create classification model
rfclassifier = RandomForestClassifier(criterion='entropy',
                                      max_features=None,
                                      n_estimators=1000,
                                      random_state=42,
                                      n_jobs=-1)

# %%
# %%time
# Fit model
models_dict['RandomForest'] = rfclassifier.fit(X_train, y_train)
# Out:
# Wall time: 43.9 s

# %% [markdown]
# #### Decision Tree

# %%
# Load libraries
from sklearn.tree import DecisionTreeClassifier

# Create classification model
decisiontree = DecisionTreeClassifier(class_weight=None,
                                      criterion='entropy',
                                      max_depth=None,
                                      max_features=None,
                                      max_leaf_nodes=300,
                                      min_samples_leaf=1,
                                      min_samples_split=2,
                                      splitter='best',
                                      random_state=42,)

# %%
# %%time
# Fit model
models_dict['DecisionTree'] = decisiontree.fit(X_train, y_train)
# Out:
# Wall time: 145 ms

# %% [markdown]
# #### AdaBoost

# %%
# Load libraries
from sklearn.ensemble import AdaBoostClassifier

# Create classification model
adaboost = AdaBoostClassifier(algorithm='SAMME',
                              learning_rate=1,
                              n_estimators=1000,
                              random_state=42)

# %%
# %%time
# Fit model
models_dict['AdaBoost'] = adaboost.fit(X_train, y_train)
# Out:
# Wall time: 6.52 s

# %% [markdown]
# #### Support Vector Classifier (SVC)

# %%
# Load libraries
from sklearn.svm import SVC

# Create classification model
svc = SVC(C=1,
          break_ties=True,
          decision_function_shape='ovr',
          gamma='scale',
          kernel='rbf',
          shrinking=True,
          tol=0.001,
          random_state=42)

# %%
# %%time
# Fit model
models_dict['SVC'] = svc.fit(X_train, y_train)
# Out:
# Wall time: 2.05 s

# %% [markdown]
# #### Gaussian Naive Bayes Classifier

# %%
# Load libraries
from sklearn.naive_bayes import GaussianNB

# Create Gaussian naive Bayes object
nBayes = GaussianNB(var_smoothing=0.1)

# %%
# %%time
# Fit model
models_dict['GaussianNB'] = nBayes.fit(X_train, y_train)
# Out:
# Wall time: 18.7 ms

# %% [markdown]
# #### MLPCClassifier

# %%
# Load libraries
from sklearn.neural_network import MLPClassifier

# Create classification model
mlp = MLPClassifier(tol=1e-5,
                    solver='adam',
                    learning_rate_init=0.01,
                    hidden_layer_sizes=(32, 68, 24),
                    epsilon=1e-9,
                    early_stopping=True,
                    alpha=1e-5,
                    activation='logistic')

# %%
# %%time
# Fit model
models_dict['MLP'] = mlp.fit(X_train, y_train)
# Out:
# Wall time: 1.88 s

# %% [markdown]
# Compare Accuracies

# %%
# %%time
# Create lists of models and accuracy scores
modelName = []
score = []
for key in models_dict:
    modelName += [key]
    model = models_dict[key]
    value = model.score(X_test, y_test)*100
    score += [round(value, 2)]

# Create DataFrame of results
d = {'Model': modelName, 'Accuracy': score}
results = pd.DataFrame(d).sort_values(by=['Accuracy'], ascending=False)
results
# Out:
# Wall time: 5.68 s
#           Model  Accuracy
# 2  DecisionTree      7.88
# 1  RandomForest      7.41
# 4           SVC      6.83
# 0      Logistic      6.47
# 6           MLP      6.47
# 3      AdaBoost      5.16
# 5    GaussianNB      3.13
