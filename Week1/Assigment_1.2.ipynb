# %% [markdown]
# # Scott Breitbach
# ## DSC630: Week 1, 29-Aug-2021
# ## 1.2 Assignment: R/Python Refresher

# %%
# Load libraries
import pandas as pd
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ### 1. *Import, Plot, Summarize, and Save Data*
# Using the [US Bureau of Labor Statistics data](https://www.bls.gov/data/tools.htm), choose a dataset that interests you. Then generate summary statistics for 2 variables, plot some of the features (e.g., histograms, box plots, density plots, etc.) of several variables, and save the data locally as CSV files.

# %%
# Data description
'''
CPI Average Price Data, U.S. city average (AP)

Series Id:	APU000074714  
Series Title:	Gasoline, unleaded regular, per gallon/3.785 liters in U.S. city average, average price, not seasonally adjusted  
Area:	U.S. city average  
Item:	Gasoline, unleaded regular, per gallon/3.785 liters
'''

# Load data to a DataFrame
gasPrices = pd.read_excel('SeriesReport_20210829184422_d810b7.xlsx', header=9, index_col=0)

# Verify data loaded correctly
gasPrices.head()
# Out:
#         Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# Year
# 1976  0.605  0.600  0.594  0.592  0.600  0.616  0.623  0.628  0.630  0.629
# 1977  0.627  0.637  0.643  0.651  0.659  0.665  0.667  0.667  0.666  0.665
# 1978  0.648  0.647  0.647  0.649  0.655  0.663  0.674  0.682  0.688  0.690
# 1979  0.716  0.730  0.755  0.802  0.844  0.901  0.949  0.988  1.020  1.028
# 1980  1.131  1.207  1.252  1.264  1.266  1.269  1.271  1.267  1.257  1.250
#
#         Nov    Dec
# Year
# 1976  0.629  0.626
# 1977  0.664  0.665
# 1978  0.695  0.705
# 1979  1.041  1.065
# 1980  1.250  1.258

# %%
# Generate summary stats for each month variable
gasPrices.describe()
# Out:
#              Jan        Feb        Mar        Apr        May        Jun  \
# count  46.000000  46.000000  46.000000  46.000000  46.000000  46.000000
# mean    1.636783   1.658391   1.720152   1.779413   1.835196   1.847935
# std     0.795673   0.830178   0.905083   0.943581   0.977918   0.969909
# min     0.605000   0.600000   0.594000   0.592000   0.600000   0.616000
# 25%     1.120000   1.088500   1.048250   1.085250   1.130750   1.134500
# 50%     1.279500   1.294500   1.268000   1.335500   1.361500   1.350000
# 75%     2.285250   2.295500   2.381500   2.468250   2.677750   2.709750
# max     3.399000   3.693000   3.868000   3.927000   3.933000   4.065000
#
#              Jul        Aug        Sep        Oct        Nov        Dec
# count  46.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# mean    1.836652   1.797578   1.802422   1.759089   1.702444   1.655711
# std     0.964086   0.929731   0.922162   0.867909   0.805296   0.775305
# min     0.623000   0.628000   0.630000   0.629000   0.629000   0.626000
# 25%     1.129250   1.158000   1.148000   1.127000   1.134000   1.123000
# 50%     1.356500   1.323000   1.307000   1.362000   1.283000   1.298000
# 75%     2.687750   2.627000   2.589000   2.484000   2.241000   2.230000
# max     4.090000   3.786000   3.856000   3.786000   3.488000   3.331000

# %%
gasPrices.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
gasPrices.mean(axis=1).plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
gasPrices.plot(kind='box', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
gasPrices.mean().plot()
# Out:
# <AxesSubplot:>

# %%
gasPrices.hist(bins=20, figsize=(10,6))
# Out:
# array([[<AxesSubplot:title={'center':'Jan'}>,
#         <AxesSubplot:title={'center':'Feb'}>,
#         <AxesSubplot:title={'center':'Mar'}>],
#        [<AxesSubplot:title={'center':'Apr'}>,
#         <AxesSubplot:title={'center':'May'}>,
#         <AxesSubplot:title={'center':'Jun'}>],
#        [<AxesSubplot:title={'center':'Jul'}>,
#         <AxesSubplot:title={'center':'Aug'}>,
#         <AxesSubplot:title={'center':'Sep'}>],
#        [<AxesSubplot:title={'center':'Oct'}>,
#         <AxesSubplot:title={'center':'Nov'}>,
#         <AxesSubplot:title={'center':'Dec'}>]], dtype=object)

# %%
# This is not helpful
gasPrices.plot.area()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
gasPrices.plot.scatter('Jan', 'Jul')
# Out:
# <AxesSubplot:xlabel='Jan', ylabel='Jul'>

# %%
gasPrices.plot.scatter('Jun', 'Jul')
# Out:
# <AxesSubplot:xlabel='Jun', ylabel='Jul'>

# %%
gasPrices.plot.scatter('Jun', 'Dec')
# Out:
# <AxesSubplot:xlabel='Jun', ylabel='Dec'>

# %%
gasPrices.plot.scatter('Jan', 'Dec')
# Out:
# <AxesSubplot:xlabel='Jan', ylabel='Dec'>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(gasPrices, diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='Jan', ylabel='Jan'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Jan'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Jan'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Jan'>,
#         <AxesSubplot:xlabel='May', ylabel='Jan'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Jan'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Jan'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Jan'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Jan'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Jan'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Jan'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Jan'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='Feb'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Feb'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Feb'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Feb'>,
#         <AxesSubplot:xlabel='May', ylabel='Feb'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Feb'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Feb'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Feb'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Feb'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Feb'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Feb'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Feb'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='Mar'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Mar'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Mar'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Mar'>,
#         <AxesSubplot:xlabel='May', ylabel='Mar'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Mar'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Mar'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Mar'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Mar'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Mar'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Mar'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Mar'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='Apr'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Apr'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Apr'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Apr'>,
#         <AxesSubplot:xlabel='May', ylabel='Apr'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Apr'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Apr'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Apr'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Apr'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Apr'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Apr'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Apr'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='May'>,
#         <AxesSubplot:xlabel='Feb', ylabel='May'>,
#         <AxesSubplot:xlabel='Mar', ylabel='May'>,
#         <AxesSubplot:xlabel='Apr', ylabel='May'>,
#         <AxesSubplot:xlabel='May', ylabel='May'>,
#         <AxesSubplot:xlabel='Jun', ylabel='May'>,
#         <AxesSubplot:xlabel='Jul', ylabel='May'>,
#         <AxesSubplot:xlabel='Aug', ylabel='May'>,
#         <AxesSubplot:xlabel='Sep', ylabel='May'>,
#         <AxesSubplot:xlabel='Oct', ylabel='May'>,
#         <AxesSubplot:xlabel='Nov', ylabel='May'>,
#         <AxesSubplot:xlabel='Dec', ylabel='May'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='Jun'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Jun'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Jun'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Jun'>,
#         <AxesSubplot:xlabel='May', ylabel='Jun'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Jun'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Jun'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Jun'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Jun'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Jun'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Jun'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Jun'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='Jul'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Jul'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Jul'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Jul'>,
#         <AxesSubplot:xlabel='May', ylabel='Jul'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Jul'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Jul'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Jul'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Jul'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Jul'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Jul'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Jul'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='Aug'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Aug'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Aug'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Aug'>,
#         <AxesSubplot:xlabel='May', ylabel='Aug'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Aug'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Aug'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Aug'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Aug'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Aug'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Aug'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Aug'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='Sep'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Sep'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Sep'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Sep'>,
#         <AxesSubplot:xlabel='May', ylabel='Sep'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Sep'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Sep'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Sep'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Sep'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Sep'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Sep'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Sep'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='Oct'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Oct'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Oct'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Oct'>,
#         <AxesSubplot:xlabel='May', ylabel='Oct'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Oct'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Oct'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Oct'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Oct'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Oct'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Oct'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Oct'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='Nov'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Nov'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Nov'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Nov'>,
#         <AxesSubplot:xlabel='May', ylabel='Nov'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Nov'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Nov'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Nov'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Nov'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Nov'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Nov'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Nov'>],
#        [<AxesSubplot:xlabel='Jan', ylabel='Dec'>,
#         <AxesSubplot:xlabel='Feb', ylabel='Dec'>,
#         <AxesSubplot:xlabel='Mar', ylabel='Dec'>,
#         <AxesSubplot:xlabel='Apr', ylabel='Dec'>,
#         <AxesSubplot:xlabel='May', ylabel='Dec'>,
#         <AxesSubplot:xlabel='Jun', ylabel='Dec'>,
#         <AxesSubplot:xlabel='Jul', ylabel='Dec'>,
#         <AxesSubplot:xlabel='Aug', ylabel='Dec'>,
#         <AxesSubplot:xlabel='Sep', ylabel='Dec'>,
#         <AxesSubplot:xlabel='Oct', ylabel='Dec'>,
#         <AxesSubplot:xlabel='Nov', ylabel='Dec'>,
#         <AxesSubplot:xlabel='Dec', ylabel='Dec'>]], dtype=object)

# %% [markdown]
# ### 2. *Eplore Some Bivariate Relations*
# Use the same dataset within the same website to explore some bivariate relations (e.g. bivariate plot, correlation, table cross table etc.).

# %% [markdown]
# ### 3. *Organize a Data Report*
# Generate a summary report. Make sure to include: summary for every variable, structure and type of data elements, discuss four results of your data.
